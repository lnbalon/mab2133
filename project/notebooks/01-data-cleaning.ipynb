# %%
import os
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
PATH = '../raw_data'

# %%
os.listdir(PATH)
# Out:
# ['governors_county_candidate.csv',
#  'president_county_candidate.csv',
#  'governors_state.csv',
#  'governors_county.csv',
#  'senate_state.csv',
#  'house_candidate.csv',
#  'senate_county.csv',
#  'president_state.csv',
#  'president_county.csv',
#  'house_state.csv',
#  'senate_county_candidate.csv']

# %%
pres_county_candidate = pd.read_csv(os.path.join(PATH, 'countypres_2000-2020.csv'))
pres_county_candidate = pres_county_candidate[pres_county_candidate['party'].isin(['DEMOCRAT', 'REPUBLICAN'])]
pres_county_candidate.head(10)
# Out:
#     year    state state_po county_name  county_fips     office  \
# 0   2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT
# 1   2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT
# 4   2000  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT
# 5   2000  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT
# 8   2000  ALABAMA       AL     BARBOUR       1005.0  PRESIDENT
# 9   2000  ALABAMA       AL     BARBOUR       1005.0  PRESIDENT
# 12  2000  ALABAMA       AL        BIBB       1007.0  PRESIDENT
# 13  2000  ALABAMA       AL        BIBB       1007.0  PRESIDENT
# 16  2000  ALABAMA       AL      BLOUNT       1009.0  PRESIDENT
# 17  2000  ALABAMA       AL      BLOUNT       1009.0  PRESIDENT
#
#          candidate       party  candidatevotes  totalvotes   version   mode
# 0          AL GORE    DEMOCRAT          4942.0     17208.0  20191203  TOTAL
# 1   GEORGE W. BUSH  REPUBLICAN         11993.0     17208.0  20191203  TOTAL
# ...

# %%
pres_county_candidate[pres_county_candidate['year'] == 2000]
# Out:
#        year    state state_po  county_name  county_fips     office  \
# 0      2000  ALABAMA       AL      AUTAUGA       1001.0  PRESIDENT
# 1      2000  ALABAMA       AL      AUTAUGA       1001.0  PRESIDENT
# 4      2000  ALABAMA       AL      BALDWIN       1003.0  PRESIDENT
# 5      2000  ALABAMA       AL      BALDWIN       1003.0  PRESIDENT
# 8      2000  ALABAMA       AL      BARBOUR       1005.0  PRESIDENT
# ...     ...      ...      ...          ...          ...        ...
# 50021  2000   ALASKA       AK  DISTRICT 39       2039.0  PRESIDENT
# 50024  2000   ALASKA       AK  DISTRICT 40       2040.0  PRESIDENT
# 50025  2000   ALASKA       AK  DISTRICT 40       2040.0  PRESIDENT
# 50028  2000   ALASKA      NaN  DISTRICT 99       2099.0  PRESIDENT
# 50029  2000   ALASKA      NaN  DISTRICT 99       2099.0  PRESIDENT
#
#             candidate       party  candidatevotes  totalvotes   version   mode
# 0             AL GORE    DEMOCRAT          4942.0     17208.0  20191203  TOTAL
# ...

# %%
pres_county_candidate['county_fips'].unique().shape
# Out:
# (3156,)

# %%
pres_county_candidate['party'].unique()
# Out:
# array(['DEM', 'REP'], dtype=object)

# %%
pres_county_candidate['county'].unique().shape, pres_county_candidate.shape
# Out:
# ((3007,), (9266, 6))

# %%
pres_county_candidate[['state','county']].drop_duplicates().shape
# Out:
# (4633, 2)

# %%
pres_county_candidate['state'].unique().shape
# Out:
# (51,)

# %% [markdown]
# There are 4633 counties in the dataset.

# %%
pres_county_grouped = pres_county_candidate.groupby('candidate', as_index=False).agg({'won': 'sum', 'total_votes': 'sum'}).sort_values('total_votes', ascending=False)

# %%
pres_county_grouped.head()
# Out:
#       candidate   won  total_votes
# 1     Joe Biden  1410     82046434
# 0  Donald Trump  3219     74585705

# %%
unemployment = pd.read_excel(os.path.join(PATH, 'Unemployment.xlsx'), header=4)

# %%
unemployment.head()
# Out:
#    FIPS_Code State           Area_name  Rural_urban_continuum_code_2013  \
# 0          0    US       United States                              NaN
# 1       1000    AL             Alabama                              NaN
# 2       1001    AL  Autauga County, AL                              2.0
# 3       1003    AL  Baldwin County, AL                              3.0
# 4       1005    AL  Barbour County, AL                              6.0
#
#    Urban_influence_code_2013  Metro_2013  Civilian_labor_force_2000  \
# 0                        NaN         NaN                142601576.0
# 1                        NaN         NaN                  2147173.0
# 2                        2.0         1.0                    21861.0
# 3                        2.0         1.0                    69979.0
# 4                        6.0         0.0                    11449.0
#
#    Employed_2000  Unemployed_2000  Unemployment_rate_2000  \
# 0    136904853.0        5696723.0                3.994853
# ...

# %%
unemployment.shape
# Out:
# (3275, 92)

# %%
unemployment['FIPS_Code'].shape
# Out:
# (3275,)

# %%
population = pd.read_excel(os.path.join(PATH, 'PopulationEstimates.xls'), header=2)

# %%
population
# Out:
#       FIPStxt State                         Area_Name  \
# 0           0    US                     United States
# 1        1000    AL                           Alabama
# 2        1001    AL                    Autauga County
# 3        1003    AL                    Baldwin County
# 4        1005    AL                    Barbour County
# ...       ...   ...                               ...
# 3268    72145    PR  Vega Baja Municipio, Puerto Rico
# 3269    72147    PR    Vieques Municipio, Puerto Rico
# 3270    72149    PR   Villalba Municipio, Puerto Rico
# 3271    72151    PR    Yabucoa Municipio, Puerto Rico
# 3272    72153    PR      Yauco Municipio, Puerto Rico
#
#       Rural-urban_Continuum Code_2003  Rural-urban_Continuum Code_2013  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 2.0                              2.0
# ...
